# %% [markdown]
# Ejercicio 81:
#
# Crea una matriz 2D con valores aleatorios y reemplaza el valor máximo en cada fila con -1.

# %%
matrix = np.random.random((3, 4))
max_values_indices = np.argmax(matrix, axis=1)
matrix[np.arange(matrix.shape[0]), max_values_indices] = -1
print(matrix)

# %% [markdown]
# Ejercicio 82:
#
# Normalizar las columnas de una matriz 2D para que tengan una suma de 1.

# %% [markdown]
# import numpy as np
# matrix = np.random.random((3, 4))
# normalized_columns = matrix / np.sum(matrix, axis=0, keepdims=True)
# print(normalized_columns)

# %%
import numpy as np
matrix = np.random.random((3, 4))
normalized_columns = matrix / np.sum(matrix, axis=0, keepdims=True)
print(normalized_columns)

# %% [markdown]
# Ejercicio 83:
#
# Encuentra los índices de los N valores mínimos superiores en una matriz unidimensional.

# %%
import numpy as np
arr = np.array([10, 5, 8, 1, 7])
top_indices = np.argsort(arr)[:2]  # Replace 2 with desired top N
print(top_indices)

# %% [markdown]
# Ejercicio 84:
#
# Convertir los elementos de una matriz unidimensional en cadenas.

# %%
import numpy as np
arr = np.array([1, 2, 3, 4])
string_arr = arr.astype(str)
print(string_arr)

# %% [markdown]
# Ejercicio 85:
#
# Calcula el rango percentil de cada elemento en una matriz unidimensional.

# %%
import numpy as np
from scipy.stats import percentileofscore
arr = np.array([1, 2, 3, 4, 5])
# Calculate percentile rank for each element in arr
percentile_rank = np.array([percentileofscore(arr, value) for value in arr])
print(percentile_rank)

# %% [markdown]
# Ejercicio 86:
#
# Crea una matriz unidimensional y baraja sus elementos aleatoriamente.

# %%
import numpy as np
arr = np.array([1, 2, 3, 4, 5])
np.random.shuffle(arr)
print(arr)

# %% [markdown]
# Ejercicio 87:
#
# Comprueba si todos los elementos de una matriz unidimensional son distintos de cero.

# %% [markdown]
# import numpy as np
# arr = np.array([1, 2, 3, 4, 5])
# all_nonzero = np.all(arr != 0)
# print(all_nonzero)

# %% [markdown]
# Ejercicio 88:
#
# Encuentra los índices del valor máximo en cada fila de una matriz 2D.

# %%
import numpy as np
matrix = np.random.random((3, 4))
max_indices_per_row = np.argmax(matrix, axis=1)
print(max_indices_per_row)

# %% [markdown]
# Ejercicio 89:
#
# Crea una matriz 2D y reemplaza todos los valores nan con la media de la matriz

# %%
import numpy as np
matrix = np.array([[1, np.nan, 3], [4, 5, np.nan], [7, 8, 9]])
nan_mean = np.nanmean(matrix)
matrix[np.isnan(matrix)] = nan_mean
print(matrix)

# %% [markdown]
# Ejercicio 90:
#
# Calcula la media de cada fila en una matriz 2D ignorando los valores nan.

# %%
import numpy as np
matrix = np.array([[1, 2, np.nan], [4, np.nan, 6], [7, 8, 9]])
row_means_ignore_nan = np.nanmean(matrix, axis=1)
print(row_means_ignore_nan)
